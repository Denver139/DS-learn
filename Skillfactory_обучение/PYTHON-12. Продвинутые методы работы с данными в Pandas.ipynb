# %%
import pandas as pd
melb_df = pd.read_csv('C:\DS\IDE\data\melb_data.csv', sep = ',')
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# 0        Yarra   -37.7996    144.9984  Northern Metropolitan         4019.0
# 1        Yarra   -37.8079    144.9934  Northern Metropolitan         4019.0
# 2        Yarra   -37.8093    144.9944  Northern Metropolitan         4019.0
# 3        Yarra   -37.7969    144.9969  Northern Metropolitan         4019.0
# 4        Yarra   -37.8072    144.9941  Northern Metropolitan         4019.0
#
#           Coordinates
# 0  -37.7996, 144.9984
# 1  -37.8079, 144.9934
# 2  -37.8093, 144.9944
# 3  -37.7969, 144.9969
# 4  -37.8072, 144.9941
#
# [5 rows x 23 columns]

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
#  17  CouncilArea    12211 non-null  object
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  object
#  21  Propertycount  13580 non-null  float64
#  22  Coordinates    13580 non-null  object
# dtypes: float64(11), int64(3), object(9)
# memory usage: 2.4+ MB
# None

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
quarters = melb_df['Date'].dt.quarter
print(quarters.value_counts().iloc[1])
# Out:
# 4359
# C:\Users\1\AppData\Local\Temp\ipykernel_6020\2136328082.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   melb_df['Date'] = pd.to_datetime(melb_df['Date'])

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] 
max_unique_count = 150 
for col in melb_df.columns: 
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: 
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  category
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  category
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  datetime64[ns]
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  category
#  17  CouncilArea    12211 non-null  category
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  category
#  21  Propertycount  13580 non-null  float64
#  22  Coordinates    13580 non-null  object
# dtypes: category(5), datetime64[ns](1), float64(10), int64(3), object(4)
# memory usage: 1.9+ MB
# None

# %%
melb_df.sort_values(by = 'Price').head(10)
# Out:
#        index          Suburb             Address  Rooms Type     Price Method  \
# 2652    2652       Footscray    202/51 Gordon St      1    u   85000.0     PI
# 1805    1805       Caulfield          30 Pyne St      4    h  131000.0     PI
# 7303    7303          Albion       8/6 Ridley St      1    u  145000.0     PI
# 1927    1927          Coburg     171 Moreland Rd      4    h  145000.0     PI
# 7940    7940        Hawthorn       17/17 Park St      1    u  160000.0     VB
# 12666  12666       Brunswick       4/831 Park St      1    u  170000.0     VB
# 8811    8811       Footscray    10/30 Pickett St      1    u  170000.0     PI
# 8504    8504  West Footscray     8/132 Rupert St      1    u  185000.0     PI
# 7293    7293          Albion  10/117 Anderson Rd      1    u  185000.0      S
# 7305    7305          Albion      5/25 Ridley St      2    u  190000.0     SP
#
#              SellerG       Date  Distance  ...  Car  Landsize  BuildingArea  \
# 2652         Burnham 2016-03-09       6.4  ...  0.0       0.0         126.0
# 1805          Rodney 2017-02-25       8.9  ...  2.0     499.0         155.0
# 7303          Biggin 2016-05-28      13.9  ...  1.0      36.0         126.0
# 1927          Jellis 2016-04-06       7.8  ...  1.0     536.0         164.0
# 7940             HAR 2017-08-04       4.6  ...  0.0     322.0         126.0
# 12666         Nelson 2017-09-16       5.2  ...  0.0    1250.0         126.0
# 8811         Burnham 2017-01-07       5.1  ...  0.0      30.0          26.0
# 8504             Jas 2017-04-29       8.2  ...  1.0       0.0         126.0
# 7293   hockingstuart 2016-08-22      13.9  ...  1.0    2347.0          43.0
# 7305         Burnham 2016-07-30      13.9  ...  1.0       0.0         126.0
#
#        YearBuilt  CouncilArea  Lattitude Longtitude             Regionname  \
# 2652      2007.0  Maribyrnong  -37.79110  144.89000   Western Metropolitan
# 1805      1920.0    Glen Eira  -37.88640  145.02420  Southern Metropolitan
# 7303      1970.0     Brimbank  -37.78330  144.82660   Western Metropolitan
# 1927      1910.0     Moreland  -37.75550  144.96580  Northern Metropolitan
# 7940      2009.0   Boroondara  -37.81980  145.03730  Southern Metropolitan
# 12666     1970.0          NaN  -37.77685  144.95188  Northern Metropolitan
# 8811      2013.0  Maribyrnong  -37.80141  144.89587   Western Metropolitan
# 8504      1970.0  Maribyrnong  -37.79800  144.86720   Western Metropolitan
# 7293      1975.0     Brimbank  -37.78520  144.82720   Western Metropolitan
# 7305      1970.0     Brimbank  -37.78390  144.82390   Western Metropolitan
#
#        Propertycount           Coordinates
# 2652          7570.0      -37.7911, 144.89
# 1805          2379.0    -37.8864, 145.0242
# 7303          2185.0    -37.7833, 144.8266
# 1927         11204.0    -37.7555, 144.9658
# 7940         11308.0    -37.8198, 145.0373
# 12666        11918.0  -37.77685, 144.95188
# 8811          7570.0  -37.80141, 144.89587
# 8504          5058.0     -37.798, 144.8672
# 7293          2185.0    -37.7852, 144.8272
# 7305          2185.0    -37.7839, 144.8239
#
# [10 rows x 23 columns]

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#        index        Suburb             Address  Rooms Type      Price Method  \
# 11144  11144     Northcote          40 Gadd St      4    h  1955000.0     SP
# 11217  11217  Surrey Hills   424 Whitehorse Rd      3    h  1775000.0     PI
# 11206  11206      St Kilda       48 Greeves St      4    h  1600000.0     VB
# 11207  11207    Strathmore         78 Bulla Rd      7    h  2000000.0     SP
# 11208  11208    Strathmore        5 Kilburn St      4    h  1610000.0      S
# ...      ...           ...                 ...    ...  ...        ...    ...
# 1555    1555    Camberwell      28 Brinsley Rd      4    h  2650000.0      S
# 4510    4510      Oak Park         14 Marie St      3    h   892000.0      S
# 4388    4388     Northcote        30 Clarke St      3    h  1200000.0      S
# 6184    6184  Surrey Hills  999A Riversdale Rd      3    h  1205000.0      S
# 6183    6183  Surrey Hills    1/10 Florence Rd      2    u   813000.0      S
#
#          SellerG       Date  Distance  ...  Car  Landsize  BuildingArea  \
# 11144    McGrath 2017-12-08       5.3  ...  1.0       5.0         126.0
# 11217     Jellis 2017-12-08      10.2  ...  2.0     780.0         126.0
# 11206       Gary 2017-12-08       5.0  ...  3.0     613.0         160.0
# 11207     Nelson 2017-12-08       8.2  ...  4.0     608.0         355.0
# 11208  Considine 2017-12-08       8.2  ...  2.0     861.0         274.0
# ...          ...        ...       ...  ...  ...       ...           ...
# 1555      Jellis 2016-03-09       7.8  ...  1.0     652.0         189.0
# 4510      Nelson 2016-03-09      11.5  ...  3.0     757.0         126.0
# 4388      Nelson 2016-03-09       5.5  ...  1.0     215.0         125.0
# 6184   Fletchers 2016-01-28      11.2  ...  2.0     490.0         126.0
# 6183   Fletchers 2016-01-28      11.2  ...  2.0     108.0         126.0
#
#        YearBuilt    CouncilArea  Lattitude Longtitude             Regionname  \
# 11144     1970.0        Darebin  -37.76280  144.99375  Northern Metropolitan
# 11217     1970.0     Boroondara  -37.81403  145.08968  Southern Metropolitan
# 11206     1910.0   Port Phillip  -37.86667  144.98324  Southern Metropolitan
# 11207     1999.0  Moonee Valley  -37.73681  144.90587   Western Metropolitan
# 11208     1955.0  Moonee Valley  -37.73154  144.92243   Western Metropolitan
# ...          ...            ...        ...        ...                    ...
# 1555      1890.0     Boroondara  -37.82860  145.06860  Southern Metropolitan
# 4510      1970.0       Moreland  -37.71800  144.91740  Northern Metropolitan
# 4388      1920.0        Darebin  -37.77590  144.99090  Northern Metropolitan
# 6184      1970.0     Whitehorse  -37.83610  145.10060  Southern Metropolitan
# 6183      1970.0     Whitehorse  -37.82760  145.10230  Southern Metropolitan
#
#        Propertycount           Coordinates
# 11144        11364.0   -37.7628, 144.99375
# 11217         5457.0  -37.81403, 145.08968
# 11206        13240.0  -37.86667, 144.98324
# 11207         3284.0  -37.73681, 144.90587
# 11208         3284.0  -37.73154, 144.92243
# ...              ...                   ...
# 1555          8920.0    -37.8286, 145.0686
# 4510          2651.0     -37.718, 144.9174
# 4388         11364.0    -37.7759, 144.9909
# 6184          5457.0    -37.8361, 145.1006
# 6183          5457.0    -37.8276, 145.1023
#
# [13580 rows x 23 columns]

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10,['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
# Empty DataFrame
# Columns: [Date, AreaRatio]
# Index: []

# %%
int(melb_df.sort_values(
    by='AreaRatio', 
    ignore_index=True,
    ascending=False
).loc[1558, 'BuildingArea'])
# Out:
# 126

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsSquare'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsSquare, Length: 13580, dtype: float64

# %%
mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2
int(melb_df[mask1&mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[18, 'Price'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: 18 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 3
#       1 mask1 = melb_df['Type'] == 'townhouse'
#       2 mask2 = melb_df['Rooms'] > 2
# ----> 3 int(melb_df[mask1&mask2].sort_values(
#       4     by=['Rooms', 'MeanRoomsSquare'],
#       5     ascending=[True, False],
#       6     ignore_index=True
#       7 ).loc[18, 'Price'])
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1066, in _LocationIndexer.__getitem__(self, key)
#    1064     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1065     if self._is_scalar_access(key):
# -> 1066         return self.obj._get_value(*key, takeable=self._takeable)
#    1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3922, in DataFrame._get_value(self, index, col, takeable)
#    3916 engine = self.index._engine
#    3918 if not isinstance(self.index, MultiIndex):
#    3919     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3920     #  results if our categories are integers that dont match our codes
#    3921     # IntervalIndex: IntervalTree has no get_loc
# -> 3922     row = self.index.get_loc(index)
#    3923     return series._values[row]
#    3925 # For MultiIndex going through engine effectively restricts us to
#    3926 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\range.py:393, in RangeIndex.get_loc(self, key, method, tolerance)
#     391         return self._range.index(new_key)
#     392     except ValueError as err:
# --> 393         raise KeyError(key) from err
#     394 self._check_indexing_error(key)
#     395 raise KeyError(key)
#
# KeyError: 18

# %%
melb_df.groupby(by='Type').mean()
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_11532\1287844458.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   melb_df.groupby(by='Type').mean()
#             index     Rooms         Price   Distance     Postcode   Bedroom  \
# Type
# h     7075.985924  3.260874  1.242665e+06  10.979479  3104.080643  3.229336
# t     6269.107720  2.837522  9.337351e+05   9.851346  3100.777379  2.814183
# u     6084.399403  1.963871  6.051275e+05   7.607391  3110.797481  1.966523
#
#       Bathroom       Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# h     1.613822  1.772674  617.181924    152.162553 -37.803795  144.994700
# t     1.809695  1.555655  279.606822    134.649710 -37.815782  144.996489
# u     1.183295  1.128936  477.314219    102.235863 -37.823710  144.996363
#
#       Propertycount  AreaRatio  MeanRoomsSquare
# Type
# h       7259.025505  -0.490031        18.996731
# t       7094.459605  -0.094916        18.569847
# u       8199.280080   0.319883        21.068242

# %%
melb_df.groupby('Type')['Price'].mean()
# Out:
# Type
# h    1.242665e+06
# t    9.337351e+05
# u    6.051275e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_df.groupby('MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 melb_df.groupby('MonthSale')['Price'].agg(
#       2     ['count', 'mean', 'max']
#       3 ).sort_values(by='count', ascending=False)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8399, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
#    8397 axis = self._get_axis_number(axis)
# -> 8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    8402     axis=axis,
#    8403     level=level,
#    8404     as_index=as_index,
#    8405     sort=sort,
#    8406     group_keys=group_keys,
#    8407     squeeze=squeeze,
#    8408     observed=observed,
#    8409     dropna=dropna,
#    8410 )
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:959, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     956 if grouper is None:
#     957     from pandas.core.groupby.grouper import get_grouper
# --> 959     grouper, exclusions, obj = get_grouper(
#     960         obj,
#     961         keys,
#     962         axis=axis,
#     963         level=level,
#     964         sort=sort,
#     965         observed=observed,
#     966         mutated=self.mutated,
#     967         dropna=self.dropna,
#     968     )
#     970 self.obj = obj
#     971 self.axis = obj._get_axis_number(axis)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'MonthSale'

# %%
melb_df.groupby('Regionname')['SellerG'].agg(
    		['nunique', set]
)
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             70
# Eastern Victoria                 18
# Northern Metropolitan           112
# Northern Victoria                16
# South-Eastern Metropolitan       52
# Southern Metropolitan           131
# Western Metropolitan             92
# Western Victoria                  9
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Holland, Jellis, Miles, One, Biggin, William,...
# Eastern Victoria            {McGrath, hockingstuart, HAR, Barry, C21, Peak...
# Northern Metropolitan       {Brad, D'Aprano, Blue, Haughton, Domain, Mille...
# Northern Victoria           {McGrath, hockingstuart, HAR, Barry, LITTLE, R...
# South-Eastern Metropolitan  {Only, REMAX, Hall, Jellis, Biggin, Ray, Thoms...
# Southern Metropolitan       {William, White, Reed, O'Donoghues, Hooper, Ro...
# Western Metropolitan        {Brad, Leeburn, Naison, Williams, Changing, Hu...
# Western Victoria            {FN, hockingstuart, HAR, Ray, Reliance, YPA, R...

# %%
melb_df.groupby('Rooms')['Price'].mean().sort_values(ascending=False)
# Out:
# Rooms
# 7     1.920700e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 8     1.602750e+06
# 4     1.445282e+06
# 3     1.076081e+06
# 10    9.000000e+05
# 2     7.750812e+05
# 1     4.338245e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
# Out:
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %%
date1 = pd.to_datetime('2017-05-01')
date2 = pd.to_datetime('2017-09-01')
mask = (date1 <= melb_df['Date']) & (melb_df['Date']<= date2)
melb_df[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=True)
# Out:
# SellerG
# Anderson            285000.0
# Galldon             387000.0
# Mindacom            400000.0
# L                   431250.0
# Redina              445000.0
#                     ...
# Marshall         253957888.0
# hockingstuart    282834310.0
# Barry            296723050.0
# Nelson           379767500.0
# Jellis           414121833.0
# Name: Price, Length: 178, dtype: float64

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Out:
# Rooms  Type
# 1      h       8.668655e+05
#        t       5.927045e+05
#        u       3.899289e+05
# 2      h       1.017238e+06
#        t       7.101585e+05
#        u       6.104905e+05
# 3      h       1.109233e+06
#        t       9.847087e+05
#        u       8.505963e+05
# 4      h       1.462283e+06
#        t       1.217092e+06
#        u       1.037476e+06
# 5      h       1.877327e+06
#        t       1.035000e+06
#        u                NaN
# 6      h       1.869508e+06
#        t                NaN
#        u       5.200000e+05
# 7      h       1.920700e+06
#        t                NaN
#        u                NaN
# 8      h       1.510286e+06
#        t                NaN
#        u       2.250000e+06
# 10     h       9.000000e+05
#        t                NaN
#        u                NaN
# Name: Price, dtype: float64

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# Type              h             t             u
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
melb_df.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round()
# Out:
# Type           h          t          u
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns='W',
    aggfunc='count'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [75], line 1
# ----> 1 melb_df.pivot_table(
#       2     values='Price',
#       3     index='Regionname',
#       4     columns='W',
#       5     aggfunc='count'
#       6 )
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8728, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8711 @Substitution("")
#    8712 @Appender(_shared_docs["pivot_table"])
#    8713 def pivot_table(
#    (...)
#    8724     sort=True,
#    8725 ) -> DataFrame:
#    8726     from pandas.core.reshape.pivot import pivot_table
# -> 8728     return pivot_table(
#    8729         self,
#    8730         values=values,
#    8731         index=index,
#    8732         columns=columns,
#    8733         aggfunc=aggfunc,
#    8734         fill_value=fill_value,
#    8735         margins=margins,
#    8736         dropna=dropna,
#    8737         margins_name=margins_name,
#    8738         observed=observed,
#    8739         sort=sort,
#    8740     )
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:166, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     163             pass
#     164     values = list(values)
# --> 166 grouped = data.groupby(keys, observed=observed, sort=sort)
#     167 msg = (
#     168     "pivot_table dropped a column because it failed to aggregate. This behavior "
#     169     "is deprecated and will raise in a future version of pandas. Select only the "
#     170     "columns that can be aggregated."
#     171 )
#     172 with rewrite_warning(
#     173     target_message="The default value of numeric_only",
#     174     target_category=FutureWarning,
#     175     new_message=msg,
#     176 ):
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8399, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
#    8397 axis = self._get_axis_number(axis)
# -> 8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    8402     axis=axis,
#    8403     level=level,
#    8404     as_index=as_index,
#    8405     sort=sort,
#    8406     group_keys=group_keys,
#    8407     squeeze=squeeze,
#    8408     observed=observed,
#    8409     dropna=dropna,
#    8410 )
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:959, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     956 if grouper is None:
#     957     from pandas.core.groupby.grouper import get_grouper
# --> 959     grouper, exclusions, obj = get_grouper(
#     960         obj,
#     961         keys,
#     962         axis=axis,
#     963         level=level,
#     964         sort=sort,
#     965         observed=observed,
#     966         mutated=self.mutated,
#     967         dropna=self.dropna,
#     968     )
#     970 self.obj = obj
#     971 self.axis = obj._get_axis_number(axis)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'W'

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
#                            median                     mean              \
# Type                            h      t    u            h           t
# Regionname
# Eastern Metropolitan        674.0  233.5  203   717.422847  269.440678
# Eastern Victoria            843.0    0.0  230  3108.960000    0.000000
# Northern Metropolitan       459.5  134.0    0   619.249092  317.325733
# Northern Victoria           724.0    0.0    0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5  240.0  199   664.306701  212.160000
# Southern Metropolitan       586.0  246.0    0   569.643881  278.858824
# Western Metropolitan        531.0  198.0   62   507.883406  244.560669
# Western Victoria            599.5    0.0    0   655.500000    0.000000
#
#
# Type                                 u
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# South-Eastern Metropolitan  357.864865
# Southern Metropolitan       466.380245
# Western Metropolitan        557.637232
# Western Victoria              0.000000

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# Regionname   Eastern Metropolitan  Eastern Victoria  Northern Metropolitan  \
# Method Type
# PI     h                  1244000            780000                 900000
#        t                   760000                 0                 632500
#        u                   650000                 0                 410000
# S      h                  1127000            675000                 920000
#        t                   828000                 0                 750000
#        u                   645750            492000                 525500
# SA     h                   932500            950000                 817500
#        t                   807500                 0                 425000
#        u                        0                 0                 616000
# SP     h                  1050000            672500                 900000
#        t                   910000                 0                 690000
#        u                   515000            400000                 470000
# VB     h                  1100000            712500                1050000
#        t                   892500                 0                 640000
#        u                   500000                 0                 450000
#
# Regionname   Northern Victoria  South-Eastern Metropolitan  \
# Method Type
# PI     h                500000                      865000
#        t                     0                     1190000
#        u                     0                      525000
# S      h                555000                      883300
#        t                     0                      875000
#        u                     0                      606000
# SA     h                540000                      880000
#        t                     0                           0
#        u                     0                           0
# SP     h                521000                      770000
#        t                     0                      800000
#        u                     0                      601000
# VB     h                690000                      850000
#        t                     0                           0
#        u                     0                      700000
#
# Regionname   Southern Metropolitan  Western Metropolitan  Western Victoria
# Method Type
# PI     h                   1725000                870000            630000
#        t                   1055000                670000                 0
#        u                    571250                360000                 0
# S      h                   1611000                870000            397500
#        t                   1135000                729000                 0
#        u                    655000                489000                 0
# SA     h                   1390000                772500                 0
#        t                   1141000                467500                 0
#        u                    580000                571000                 0
# SP     h                   1521750                865000            360000
#        t                   1162500                702500                 0
#        u                    550000                460000                 0
# VB     h                   1800000                880000                 0
#        t                   1250000                689500                 0
#        u                    500000                420000                 0

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)

# %%
pivot.columns
# Out:
# MultiIndex([('median', 'h'),
#             ('median', 't'),
#             ('median', 'u'),
#             (  'mean', 'h'),
#             (  'mean', 't'),
#             (  'mean', 'u')],
#            names=[None, 'Type'])

# %%
display(pivot['mean']['u'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: u, dtype: float64

# %%
mask = pivot['mean']['h'] < pivot['median']['h']
filtered_pivot = pivot[mask]
display(filtered_pivot)
# Out:
#                       median                   mean
# Type                       h      t   u           h           t           u
# Regionname
# Southern Metropolitan  586.0  246.0   0  569.643881  278.858824  466.380245
# Western Metropolitan   531.0  198.0  62  507.883406  244.560669  557.637232

# %%
pivot = melb_df.pivot_table(
    values='BuildingArea',
    index='Type',
    columns='Rooms',
    aggfunc='median',
    fill_value=0
)
display(pivot)
# Out:
# Rooms     1    2    3      4    5    6      7    8    10
# Type
# h      126.0  126  126  141.0  177  126  216.5  126  126
# t       88.0  114  126  159.5  152    0    0.0    0    0
# u       69.5  110  126  126.0    0  171    0.0  126    0

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# Type              h             t             u
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
pivot = melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc='median',
)
max_unit_price = pivot['u'].max()
print(pivot[pivot['u'] == max_unit_price].index[0])
# Out:
# Scott

# %%
ratings1 = pd.read_csv('data/ratings1.csv', sep = ',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 ratings1 = pd.read_csv('data/ratings1.csv', sep = ',')
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/ratings1.csv'

# %%
dates = pd.read_csv('C:\DS\IDE\data\movies_data\dates.csv', sep = ',')
movies = pd.read_csv('C:\DS\IDE\data\movies_data\movies.csv', sep = ',')
ratings1 = pd.read_csv('C:\DS\IDE\data\movies_data\ratings1.csv', sep = ',')
ratings2 = pd.read_csv('C:\DS\IDE\data\movies_data\ratings2.csv', sep = ',')

movies.head(10)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [28], line 3
#       1 dates = pd.read_csv('C:\DS\IDE\data\movies_data\dates.csv', sep = ',')
#       2 movies = pd.read_csv('C:\DS\IDE\data\movies_data\movies.csv', sep = ',')
# ----> 3 ratings1 = pd.read_csv('C:\DS\IDE\data\movies_data\r1.csv', sep = ',')
#       4 ratings2 = pd.read_csv('C:\DS\IDE\data\movies_data\ratings2.csv', sep = ',')
#       6 movies.head(10)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 22] Invalid argument: 'C:\\DS\\IDE\\data\\movies_data\r1.csv'
